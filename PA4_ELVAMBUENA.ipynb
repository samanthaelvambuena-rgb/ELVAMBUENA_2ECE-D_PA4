# %%
import pandas as pd

# %% [markdown]
# # A. VISAYAS COMMUNICATION DATAFRAME

# %%
whole=pd.read_excel('board2.xlsx')
whole
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon  58.0         89.0  75.0
# 1    S2  Female     Communication  Mindanao  52.0         75.0  90.0
# 2    S3  Female   Instrumentation  Mindanao  83.0         74.0  77.0
# 3    S4    Male   Instrumentation   Visayas  65.0         58.0  91.0
# 4    S5    Male     Communication     Luzon  59.0         86.0  43.0
# 5    S6  Female  Microelectronics   Visayas  88.0         45.0  86.0
# 6    S7  Female   Instrumentation     Luzon  66.0         60.0  60.0
# 7    S8    Male   Instrumentation     Luzon  49.0         81.0  64.0
# 8    S9    Male   Instrumentation     Luzon  50.0         36.0  63.0
# 9   S10    Male  Microelectronics  Mindanao  80.0         84.0  61.0
# 10  S11  Female     Communication   Visayas  48.0         56.0  48.0
# 11  S12    Male     Communication   Visayas  89.0         67.0  84.0
# 12  S13  Female  Microelectronics     Luzon  88.0         35.0  83.0
# 13  S14  Female  Microelectronics     Luzon  83.0         77.0  89.0
# 14  S15  Female  Microelectronics  Mindanao  69.0         41.0  40.0
# 15  S16  Female     Communication     Luzon  71.0         70.0  87.0
# 16  S17  Female  Microelectronics  Mindanao  81.0         79.0  77.0
# 17  S18    Male     Communication   Visayas  81.0         40.0  81.0
# 18  S19    Male  Microelectronics     Luzon  79.0         63.0  79.0
# 19  S20  Female     Communication  Mindanao  59.0         60.0  62.0
# 20  S21  Female  Microelectronics   Visayas  83.0         51.0  68.0
# 21  S22  Female     Communication   Visayas  64.0         39.0  89.0
# 22  S23    Male   Instrumentation     Luzon  84.0         70.0  74.0
# 23  S24  Female  Microelectronics   Visayas  85.0         45.0  60.0
# 24  S25    Male     Communication     Luzon  74.0         91.0  94.0
# 25  S26  Female   Instrumentation   Visayas  71.0         47.0  83.0
# 26  S27    Male  Microelectronics   Visayas  70.0         47.0  40.0
# 27  S28    Male     Communication   Visayas  85.0         53.0  80.0
# 28  S29    Male   Instrumentation  Mindanao  73.0         48.0  71.0
# 29  S30    Male   Instrumentation     Luzon  78.0         81.0  57.0
#
#     Communication
# 0            78.0
# 1            52.0
# 2            57.0
# 3            68.0
# 4            88.0
# 5            83.0
# 6            48.0
# 7            53.0
# 8            42.0
# 9            44.0
# 10           67.0
# 11           64.0
# 12           43.0
# 13           73.0
# 14           86.0
# 15           81.0
# 16           45.0
# 17           52.0
# 18           71.0
# 19           85.0
# 20           72.0
# 21           58.0
# 22           47.0
# 23           41.0
# 24           42.0
# 25           62.0
# 26           86.0
# 27           53.0
# 28           62.0
# 29           56.0

# %%
whole['Average']=whole[['Math', 'Electronics', 'GEAS', 'Communication']].mean(axis=1)
whole
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luz
# %%
print('Number of Rows',len(VisComm))
# Out:
# Number of Rows 5

# %% [markdown]
# # B. VISAYAS FEMALE DATAFRAME

# %%
VisFemale=whole.loc[(whole['Hometown']=='Visayas')&(whole['Gender']=='Female'), ['Name', 'Track', 'GEAS', 'Electronics', 'Average']]
VisFemale
# Out:
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics  86.0         45.0    75.50
# 10  S11     Communication  48.0         56.0    54.75
# 20  S21  Microelectronics  68.0         51.0    68.50
# 21  S22     Communication  89.0         39.0    62.50
# 23  S24  Microelectronics  60.0         45.0    57.75
# 25  S26   Instrumentation  83.0         47.0    65.75

# %%
VisFemale.loc[(VisFemale['Average']>=60)]
# Out:
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics  86.0         45.0    75.50
# 20  S21  Microelectronics  68.0         51.0    68.50
# 21  S22     Communication  89.0         39.0    62.50
# 25  S26   Instrumentation  83.0         47.0    65.75

# %% [markdown]
# # C. CATEGORY-AVERAGE VISUALIZATION

# %%
track_mean=whole.groupby('Track')['Average'].mean().reset_index()

# %%
gender_mean=whole.groupby('Gender')['Average'].mean().reset_index()

# %%
hometown_mean=whole.groupby('Hometown')['Average'].mean().reset_index()

# %%
print('Mean of Average for TRACK:')
display(track_mean)

print('Mean of Average for GENDER:')
display(gender_mean)

print('Mean of Average for HOMETOWN:')
display(hometown_mean)
# Out:
# Mean of Average for TRACK:
#               Track  Average
# 0     Communication   67.975
# 1   Instrumentation   65.225
# 2  Microelectronics   67.500
# Mean of Average for GENDER:
#    Gender    Average
# 0  Female  66.616667
# 1    Male  67.183333
# Mean of Average for HOMETOWN:
#    Hometown    Average
# 0     Luzon  68.083333
# 1  Mindanao  66.678571
# 2   Visayas  65.750000

# %%
track_max=track_mean.max()
gender_max=gender_mean.max()
hometown_max=hometown_mean.max()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,6))

plt.subplot(1,3,1)
plt.bar(track_mean['Track'], track_mean['Average'])
plt.title('Mean Average by Track')
plt.xlabel('Track')
plt.ylabel('Mean Average Score')

plt.subplot(1,3,2)
plt.bar(gender_mean['Gender'], gender_mean['Average'])
plt.title('Mean Average by Gender')
plt.xlabel('Gender')
plt.ylabel('Mean Average Score')

plt.subplot(1,3,3)
plt.bar(hometown_mean['Hometown'], hometown_mean['Average'])
plt.title('Mean Average by Hometown')
plt.xlabel('Hometown')
plt.ylabel('Mean Average Score')

plt.tight_layout()
plt.show()

print('The TRACK that has the highest mean average across all track is:')
print(track_max)

print('The GENDER that has the highest mean average across all track is:')
print(gender_max)

print('The HOMETOWN that has the highest mean average across all track is:')
print(hometown_max)
# Out:
# The TRACK that has the highest mean average across all track is:
# Track      Microelectronics
# Average              67.975
# dtype: object
# The GENDER that has the highest mean average across all track is:
# Gender          Male
# Average    67.183333
# dtype: object
# The HOMETOWN that has the highest mean average across all track is:
# Hometown      Visayas
# Average     68.083333
# dtype: object
